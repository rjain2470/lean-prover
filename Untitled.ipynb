# %%
# !which python
# Out:
# /Users/jain/opt/anaconda3/bin/python

# %%
import rag_prover
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 import rag_prover
#
# ModuleNotFoundError: No module named 'rag_prover'
