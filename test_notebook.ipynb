# %% [markdown]
# # RAG-Prover Test Notebook
#
# This notebook demonstrates how to import and use the RAG-Prover package.

# %%
import src
print(f"RAG-Prover version: {src.__version__}")
print(f"Available functions: {src.__all__}")

# %%
from src import embed, k_nearest, build_prompt, load_decl_types
print("Functions imported successfully!")

# %% [markdown]
# ## Using the RAG-Prover Functions
#
# Note: To use `k_nearest`, you'll need:
# 1. The FAISS index file at `datasets/mathlib4_hnsw.faiss`
# 2. The names file at `datasets/mathlib4_hnsw.names.npy`
# 3. An OpenAI API key set as the `OPENAI_API_KEY` environment variable
#
# Example usage (uncomment when you have the required files):
#
# ```python
# # Find nearest neighbors for a query
# results = k_nearest("∀ n m : ℕ, n + m = m + n", k=5)
# for name, distance in results:
#     print(f"{distance:.3f}  {name}")
#
# # Build a prompt for the prover
# neighbours = [name for name, _ in results]
# prompt = build_prompt("∀ n m : ℕ, n + m = m + n", neighbours)
# print(prompt)
# ```
