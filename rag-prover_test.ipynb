# %%
import sys
sys.path.append('/Users/jain/rag-prover')
import src

# %%
import pydantic
print(pydantic.VERSION)

from pydantic_core import __version__ as pydantic_core_version
print("pydantic-core version:", pydantic_core_version)
# Out:
# 2.12.5
# pydantic-core version: 2.41.5

# %%
from src import embed_jsonl_to_vecs, build_prompt

print(embed_jsonl_to_vecs.__doc__)  # Check the docstring of a core function
print(build_prompt.__doc__)  # Check if this works too
# Out:
#     Stream `jsonl_path` through the embedding endpoint and write a raw
#     float32 matrix to `vec_path`.  Returns (row_count, dim).
#
#
#     Returns a tuple (prompt, formal_statement).
#
#     • Section 1  – bullets with *name : type*
#     • Section 2  – the same types only (no names)
